# %%
! /opt/bin/nvidia-smi
# Out:
# /bin/sh: 1: /opt/bin/nvidia-smi: not found

# %%
# !rm -r DBPN-Deep_Back_Projection_Network-Keras
# Out:
# rm: cannot remove 'DBPN-Deep_Back_Projection_Network-Keras': No such file or directory

# %%
# !git clone https://github.com/b4435242/DBPN-Deep_Back_Projection_Network-Keras.git
# Out:
# Cloning into 'DBPN-Deep_Back_Projection_Network-Keras'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 152 (delta 64), reused 69 (delta 34), pack-reused 53
# Receiving objects: 100% (152/152), 148.49 MiB | 13.31 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
# !python3 DBPN-Deep_Back_Projection_Network-Keras/SRIP_DATA_BUILDER.py

# %%
#!python3 DBPN-Deep_Back_Projection_Network-Keras/main.py --lr 0.0004 --scale 3 --to 30  --folder ./ --test_image DBPN-Deep_Back_Projection_Network-Keras/0016.png
#!python3 DBPN-Deep_Back_Projection_Network-Keras/main.py --lr 0.0002 --scale 3 --chk 29 --to 40   --folder ./ --test_image DBPN-Deep_Back_Projection_Network-Keras/0016.png
#!python3 DBPN-Deep_Back_Projection_Network-Keras/main.py --lr 0.0001 --scale 3 --chk 39 --to 51 --folder ./ --test_image DBPN-Deep_Back_Projection_Network-Keras/0016.png
# !python3 DBPN-Deep_Back_Projection_Network-Keras/main.py --lr 0.00005 --scale 3 --chk 50 --to 61 --folder ./ --test_image DBPN-Deep_Back_Projection_Network-Keras/0016.png
# !python3 DBPN-Deep_Back_Projection_Network-Keras/main.py --lr 0.00001 --scale 3 --chk 60 --to 71 --folder ./ --test_image DBPN-Deep_Back_Projection_Network-Keras/0016.png

# %%
import glob
test_imgs = glob.glob('../input/hw4imagessss/testing_lr_images/*.png')
for img in test_imgs:
  # !python3 DBPN-Deep_Back_Projection_Network-Keras/main.py --scale 3 --test_only True --chk 70 --folder testing_lr_images --test_image $img
# Out:
# 2021-01-07 06:44:16.022023: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2199995000 Hz
# 2021-01-07 06:44:16.022854: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x561ac03ed1e0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-01-07 06:44:16.022905: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# loading existing weights !!!
# (864, 864, 3)
# 2021-01-07 06:45:37.804184: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2199995000 Hz
# 2021-01-07 06:45:37.804545: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55943371e340 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-01-07 06:45:37.804593: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# loading existing weights !!!
# (576, 288, 3)
# ...

# %%
from IPython.display import FileLink
FileLink(r'results/11.png')
FileLink(r'results/12.png')
# Out:
# /kaggle/working/results/12.png

# %%
# !zip -r sr.zip ./results t
